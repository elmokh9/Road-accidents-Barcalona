# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("brazil-2019.csv",  sep = ";", encoding='latin-1', on_bad_lines='skip')

# %%
df.head(10)
# Out:
#          id data_inversa  dia_semana   horario  uf     br     km  \
# 0  182210.0   2019-01-01           3  01:30:00  SP  116.0    218
# 1  182211.0   2019-01-01           3  01:30:00  PR  373.0  177,3
# 2  182212.0   2019-01-01           3  00:45:00  SC  101.0     16
# 3  182214.0   2019-01-01           3  00:00:00  CE   20.0  429,5
# 4  182215.0   2019-01-01           3  01:00:00  MG  381.0    327
# 5  182216.0   2019-01-01           3  01:50:00  SC  470.0   42,6
# 6  182217.0   2019-01-01           3  01:30:00  MS  163.0  721,5
# 7  182219.0   2019-01-01           3  00:50:00  GO   50.0  280,3
# 8  182220.0   2019-01-01           3  02:25:00  GO   60.0    172
# 9  182223.0   2019-01-01           3  02:15:00  RS  386.0   73,7
#
#                municipio                                     causa_acidente  \
# 0              GUARULHOS                        Falta de Atenção à Condução
# 1           PONTA GROSSA                        Falta de Atenção à Condução
# ...

# %%
df.shape
# Out:
# (15588, 30)

# %%
df.columns
# Out:
# Index(['id', 'data_inversa', 'dia_semana', 'horario', 'uf', 'br', 'km',
#        'municipio', 'causa_acidente', 'tipo_acidente',
#        'classificacao_acidente', 'fase_dia', 'sentido_via',
#        'condicao_metereologica', 'tipo_pista', 'tracado_via', 'uso_solo',
#        'pessoas', 'mortos', 'feridos_leves', 'feridos_graves', 'ilesos',
#        'ignorados', 'feridos', 'veiculos', 'latitude', 'longitude', 'regional',
#        'delegacia', 'uop'],
#       dtype='object')

# %%
dictt = {'id', 'date', 'weekday', 'time', 'uf', 'br', 'km',
'municipality', 'accident_cause', 'accident_type','classified_accident', 'phase_day', 'sense_via','weather_condition', 'track_type', 'traced_via', 'use_only','people', 'dead', 'mild_injured', 'severe_injured', 'injured','ignored', 'injured', 'vehicles', 'latitude', 'longitude', 'regional','delegacy', 'uop'}

# %%
dict1 = {'data_inversa': 'date', 'dia_semana': 'weekday', 'horario':'time',
       'municipio': 'municipality', 'causa_acidente':'accident_cause', 'tipo_acidente':'accident_type',
       'classificacao_acidente':'classified_accident', 'fase_dia':'phase_day', 'sentido_via':'sense_via',
       'condicao_metereologica':'weather_condition', 'tipo_pista':'track_type', 'tracado_via':'traced_via', 'uso_solo':'use_only',
       'pessoas':'people', 'mortos':'dead', 'feridos_leves':'mild_injured', 'feridos_graves':'severe_injured', 'ilesos':'unharmed',
       'ignorados':'ignored', 'feridos':'injured', 'veiculos':'vehicles', 
       'delegacia':'delegacy'}

# %%
df.rename(columns=dict1,
          inplace=True)

# %%
df.head()
# Out:
#          id        date  weekday      time  uf     br     km  municipality  \
# 0  182210.0  2019-01-01        3  01:30:00  SP  116.0    218     GUARULHOS
# 1  182211.0  2019-01-01        3  01:30:00  PR  373.0  177,3  PONTA GROSSA
# 2  182212.0  2019-01-01        3  00:45:00  SC  101.0     16        GARUVA
# 3  182214.0  2019-01-01        3  00:00:00  CE   20.0  429,5     FORTALEZA
# 4  182215.0  2019-01-01        3  01:00:00  MG  381.0    327      NOVA ERA
#
#                         accident_cause                accident_type  ...  \
# 0          Falta de Atenção à Condução  Colisão com objeto estático  ...
# 1          Falta de Atenção à Condução             Colisão traseira  ...
# 2                     Animais na Pista  Colisão com objeto estático  ...
# 3  Ingestão de Substâncias Psicoativas  Colisão com objeto estático  ...
# 4          Falta de Atenção à Condução          Colisão transversal  ...
#
#   severe_injured unharmed ignored injured vehicles  latitude  longitude  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'weekday', 'time', 'uf', 'br', 'km', 'municipality',
#        'accident_cause', 'accident_type', 'classified_accident', 'phase_day',
#        'sense_via', 'weather_condition', 'track_type', 'traced_via',
#        'use_only', 'people', 'dead', 'mild_injured', 'severe_injured',
#        'unharmed', 'ignored', 'injured', 'vehicles', 'latitude', 'longitude',
#        'regional', 'delegacy', 'uop'],
#       dtype='object')

# %%
df.columns.get_loc('uop')
# Out:
# 29

# %%
df1 = df.drop(df.columns[[0, 4, 5, 6, 28, 29]], axis ='columns')

# %%
df1.head()
# Out:
#          date  weekday      time  municipality  \
# 0  2019-01-01        3  01:30:00     GUARULHOS
# 1  2019-01-01        3  01:30:00  PONTA GROSSA
# 2  2019-01-01        3  00:45:00        GARUVA
# 3  2019-01-01        3  00:00:00     FORTALEZA
# 4  2019-01-01        3  01:00:00      NOVA ERA
#
#                         accident_cause                accident_type  \
# 0          Falta de Atenção à Condução  Colisão com objeto estático
# 1          Falta de Atenção à Condução             Colisão traseira
# 2                     Animais na Pista  Colisão com objeto estático
# 3  Ingestão de Substâncias Psicoativas  Colisão com objeto estático
# 4          Falta de Atenção à Condução          Colisão transversal
#
#    classified_accident    phase_day    sense_via weather_condition  ... dead  \
# 0  Com Vítimas Feridas  Plena Noite    Crescente         Céu Claro  ...    0
# 1  Com Vítimas Feridas  Plena Noite    Crescente           Nublado  ...    0
# ...

# %%
def uniquePortList(df, col):
    listt = []
    listt = df.loc[:,col].unique()
    return(listt.tolist())

# %%
from googletrans import Translator, constants
from pprint import pprint
# init the Google API translator
translator = Translator()

# %%
# translate a spanish text to english text (by default)
def convertLang(portList): 
    convList =[]
    translations = translator.translate(portList, src='pt')
    for translation in translations:
        convList.append(translation.text)
    return convList

# %%
df1.head(2)
# Out:
#          date  weekday      time  municipality               accident_cause  \
# 0  2019-01-01        3  01:30:00     GUARULHOS  Falta de Atenção à Condução
# 1  2019-01-01        3  01:30:00  PONTA GROSSA  Falta de Atenção à Condução
#
#                  accident_type  classified_accident    phase_day  sense_via  \
# 0  Colisão com objeto estático  Com Vítimas Feridas  Plena Noite  Crescente
# 1             Colisão traseira  Com Vítimas Feridas  Plena Noite  Crescente
#
#   weather_condition  ... dead mild_injured severe_injured  unharmed  ignored  \
# 0         Céu Claro  ...    0            4              0         0        0
# 1           Nublado  ...    0            1              0         0        0
#
#    injured  vehicles  latitude  longitude  regional
# 0        4         1 -23.46052 -46.487725     SR-SP
# 1        1         1 -25.05534 -50.227768     SR-PR
#
# [2 rows x 24 columns]

# %%
def conversion(df):
    col_name = ['accident_cause', 'accident_type', 'classified_accident', 'phase_day', 'sense_via', 'weather_condition', 'track_type', 'traced_via','use_only']
    for n in range(len(col_name)):
        
        portList = []
        uniqueEngList = []
        
        curr_col = col_name[n]
        print(curr_col)
        portList = uniquePortList(df, curr_col)
        
        #convert
        uniqueEngList = convertLang(portList)
        
        for i in range(len(portList)):

            df.loc[df1[curr_col] == portList[i], curr_col] = uniqueEngList[i]
df2 = df1
conversion(df2)
# Out:
# accident_cause
# accident_type
# classified_accident
# phase_day
# sense_via
# weather_condition
# track_type
# traced_via
# use_only

# %%
df2.head()
# Out:
#          date  weekday      time  municipality  \
# 0  2019-01-01        3  01:30:00     GUARULHOS
# 1  2019-01-01        3  01:30:00  PONTA GROSSA
# 2  2019-01-01        3  00:45:00        GARUVA
# 3  2019-01-01        3  00:00:00     FORTALEZA
# 4  2019-01-01        3  01:00:00      NOVA ERA
#
#                          accident_cause                 accident_type  \
# 0          Lack of Attention to Driving  Collision with static object
# 1          Lack of Attention to Driving                rear collision
# 2                  Animals on the Track  Collision with static object
# 3  Ingestion of Psychoactive Substances  Collision with static object
# 4          Lack of Attention to Driving          Transverse collision
#
#     classified_accident   phase_day   sense_via weather_condition  ... dead  \
# 0  With injured victims  Full Night     Growing         Clear sky  ...    0
# 1  With injured victims  Full Night     Growing            Cloudy  ...    0
# ...

# %%
df2.isnull().any()
# Out:
# date                   False
# weekday                False
# time                   False
# municipality           False
# accident_cause         False
# accident_type          False
# classified_accident    False
# phase_day              False
# sense_via              False
# weather_condition      False
# track_type             False
# traced_via             False
# use_only               False
# people                 False
# dead                   False
# mild_injured           False
# severe_injured         False
# unharmed               False
# ignored                False
# injured                False
# vehicles               False
# latitude               False
# longitude              False
# regional               False
# dtype: bool

# %%
df.std()
# Out:
# C:\Users\ESHAN\AppData\Local\Temp\ipykernel_31192\3390915376.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# id                5211.997395
# weekday              2.093717
# br                 131.542100
# people               2.164971
# dead                 0.322379
# mild_injured         1.191322
# severe_injured       0.657402
# unharmed             1.643007
# ignored              0.391314
# injured              1.366024
# vehicles             0.743190
# latitude             7.776793
# longitude            6.117747
# dtype: float64

# %%
df2['dead'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
df2['severe_injured'].unique()
# Out:
# array([ 0,  1,  2,  3,  4, 22,  5,  6,  7, 12, 18,  8,  9], dtype=int64)

# %%
df2[df2['severe_injured'] > 15]
# Out:
#             date  weekday      time municipality  \
# 443   2019-01-03        5  08:45:00       SEABRA
# 8244  2019-01-27        1  02:30:00      GOIANIA
#
#                         accident_cause   accident_type classified_accident  \
# 443   Mechanical Defect in the Vehicle  rear collision  With fatal victims
# 8244      Lack of Attention to Driving   Cart bed exit  With fatal victims
#
#        phase_day   sense_via weather_condition  ... dead mild_injured  \
# 443     Full day  Descending         Clear sky  ...    1           14
# 8244  Full Night     Growing            Cloudy  ...    2           31
#
#      severe_injured  unharmed  ignored  injured  vehicles   latitude  \
# 443              22         0        2       36         4 -12.485007
# 8244             18         0        1       49         1 -16.695795
#
#       longitude  regional
# 443  -41.736130     SR-BA
# 8244 -49.231721     SR-GO
#
# [2 rows x 24 columns]

# %%
df2['severe_injured'].describe()
# Out:
# count    15588.000000
# mean         0.272517
# std          0.657402
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         22.000000
# Name: severe_injured, dtype: float64

# %%
fig, ax = plt.subplots(1, 2, sharey=True, tight_layout=True)
ax[0].hist(df2['severe_injured'])
ax[1].hist(df2['dead'])
# Out:
# (array([1.4566e+04, 9.0000e+02, 0.0000e+00, 8.7000e+01, 0.0000e+00,
#         2.3000e+01, 6.0000e+00, 0.0000e+00, 5.0000e+00, 1.0000e+00]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
df2['dead'].describe()
# Out:
# count    15588.000000
# mean         0.076854
# std          0.322379
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          6.000000
# Name: dead, dtype: float64

# %% [markdown]
# Severly injured is our desired metric, cos then an ambulance will be called for sure

# %%
df2.corr()
# Out:
# C:\Users\ESHAN\AppData\Local\Temp\ipykernel_31192\1778878097.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr()
#                  weekday    people      dead  mild_injured  severe_injured  \
# weekday         1.000000  0.005807  0.003336     -0.014907       -0.003305
# people          0.005807  1.000000  0.132299      0.550208        0.295386
# dead            0.003336  0.132299  1.000000     -0.070430        0.083406
# mild_injured   -0.014907  0.550208 -0.070430      1.000000        0.009320
# severe_injured -0.003305  0.295386  0.083406      0.009320        1.000000
# unharmed        0.021683  0.744412 -0.023305      0.024192       -0.044052
# ignored        -0.010725  0.126711  0.080266     -0.059563        0.042137
# injured        -0.014591  0.621996 -0.021283      0.876594        0.489380
# ...

# %%
#municipality and severly injured/dead plot
plt.scatter(df2['municipality'], df2['severe_injured'])

# %%
len(df2['municipality'].unique())
# Out:
# 1471

# %%
df2.head()
# Out:
#          date  weekday      time  municipality  \
# 0  2019-01-01        3  01:30:00     GUARULHOS
# 1  2019-01-01        3  01:30:00  PONTA GROSSA
# 2  2019-01-01        3  00:45:00        GARUVA
# 3  2019-01-01        3  00:00:00     FORTALEZA
# 4  2019-01-01        3  01:00:00      NOVA ERA
#
#                          accident_cause                 accident_type  \
# 0          Lack of Attention to Driving  Collision with static object
# 1          Lack of Attention to Driving                rear collision
# 2                  Animals on the Track  Collision with static object
# 3  Ingestion of Psychoactive Substances  Collision with static object
# 4          Lack of Attention to Driving          Transverse collision
#
#     classified_accident   phase_day   sense_via weather_condition  ... dead  \
# 0  With injured victims  Full Night     Growing         Clear sky  ...    0
# 1  With injured victims  Full Night     Growing            Cloudy  ...    0
# ...

# %%
ax = df2.dead.hist()
ax.set_yscale('log')
ax.set_xlabel('death')
ax.set_ylabel('number of accidents')
# Out:
# Text(0, 0.5, 'number of accidents')

# %% [markdown]
# Most accidents cause death 0 - 1.

# %%
df2[df2['dead']>=3]['accident_cause']
# Out:
# 151                     Lack of Attention to Driving
# 473      Disobedience to traffic rules by the driver
# 736                                 Undue Overtaking
# 1912               Tire damage and/or excessive wear
# 2487                                 Driver Sleeping
# 3030     Disobedience to traffic rules by the driver
# 3072     Disobedience to traffic rules by the driver
# 4098     Disobedience to traffic rules by the driver
# 4118                                Undue Overtaking
# 4162                                 Driver Sleeping
# 4182     Disobedience to traffic rules by the driver
# 4276                              Incompatible Speed
# 4901     Disobedience to traffic rules by the driver
# 5369                                 Driver Sleeping
# 5374                                Undue Overtaking
# 5531                    Lack of Attention to Driving
# 5727     Disobedience to traffic rules by the driver
# 5870                              Incompatible Speed
# ...

# %%
df2['weekday'].unique()
# Out:
# array([3, 4, 5, 6, 7, 1, 2], dtype=int64)

# %% [markdown]
# 1 is Sunday

# %%
df2['phase_day'].unique()
# Out:
# array(['Full Night', 'Dawn', 'Full day', 'Dusk'], dtype=object)

# %%
#Go ahead with Linear regression, Decision tree,...

# %%
df2.head(2)
# Out:
#          date  weekday      time  municipality                accident_cause  \
# 0  2019-01-01        3  01:30:00     GUARULHOS  Lack of Attention to Driving
# 1  2019-01-01        3  01:30:00  PONTA GROSSA  Lack of Attention to Driving
#
#                   accident_type   classified_accident   phase_day sense_via  \
# 0  Collision with static object  With injured victims  Full Night   Growing
# 1                rear collision  With injured victims  Full Night   Growing
#
#   weather_condition  ... dead mild_injured severe_injured  unharmed  ignored  \
# 0         Clear sky  ...    0            4              0         0        0
# 1            Cloudy  ...    0            1              0         0        0
#
#    injured  vehicles  latitude  longitude  regional
# 0        4         1 -23.46052 -46.487725     SR-SP
# 1        1         1 -25.05534 -50.227768     SR-PR
#
# [2 rows x 24 columns]

# %% [markdown]
# So the y column, which is to be predicted has to be one where ambulance is called. REad the studies to figure out severity limit
# for an accident. I am taking deaths and severly injured and feature engineering to make a column ambulance_call.

# %%
df2['severe_injured'].unique()
# Out:
# array([ 0,  1,  2,  3,  4, 22,  5,  6,  7, 12, 18,  8,  9], dtype=int64)

# %%
df['dead'] != 0
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15583    False
# 15584     True
# 15585    False
# 15586    False
# 15587    False
# Name: dead, Length: 15588, dtype: bool

# %%
df2[df2['dead'] != 0][:]
# Out:
#              date  weekday      time      municipality  \
# 8      2019-01-01        3  02:25:00           GOIANIA
# 16     2019-01-01        3  03:00:00        CAJAZEIRAS
# 17     2019-01-01        3  03:30:00           MACAIBA
# 19     2019-01-01        3  04:00:00           IPUIUNA
# 20     2019-01-01        3  03:50:00    ANGRA DOS REIS
# ...           ...      ...       ...               ...
# 15550  2019-03-07        5  13:00:00           INDIARA
# 15557  2019-03-09        7  14:20:00     GLORIA DOESTE
# 15569  2019-03-22        6  18:45:00  BARRA DO RIBEIRO
# 15573  2019-02-08        6  13:45:00           VILHENA
# 15584  2019-01-29        3  16:50:00          TERESINA
#
#                                     accident_cause            accident_type  \
# 8          Disobeying traffic rules by pedestrians  Pedestrian Running Over
# 16                    Lack of Attention to Driving        Head-on collision
# ...

# %% [markdown]
# #This was done to get a dataset where ambulance will be called. But we dont need it, we want data both where ambulance is called
# #where it isnt so that the model could learn.
# def create_y(df):
#     new_df = df[(df['dead'] != 0) & (df['severe_injured'] != 0)][:]
#     return new_df
# df3 = create_y(df2)

# %%
df2.head()
# Out:
#          date  weekday      time  municipality  \
# 0  2019-01-01        3  01:30:00     GUARULHOS
# 1  2019-01-01        3  01:30:00  PONTA GROSSA
# 2  2019-01-01        3  00:45:00        GARUVA
# 3  2019-01-01        3  00:00:00     FORTALEZA
# 4  2019-01-01        3  01:00:00      NOVA ERA
#
#                          accident_cause                 accident_type  \
# 0          Lack of Attention to Driving  Collision with static object
# 1          Lack of Attention to Driving                rear collision
# 2                  Animals on the Track  Collision with static object
# 3  Ingestion of Psychoactive Substances  Collision with static object
# 4          Lack of Attention to Driving          Transverse collision
#
#     classified_accident   phase_day   sense_via weather_condition  ... dead  \
# 0  With injured victims  Full Night     Growing         Clear sky  ...    0
# 1  With injured victims  Full Night     Growing            Cloudy  ...    0
# ...

# %%
#Causes of high no of accidents
cause_freq = df2['accident_cause'].value_counts().to_frame()
cause_freq
# Out:
#                                                     accident_cause
# Lack of Attention to Driving                                  5600
# Disobedience to traffic rules by the driver                   1740
# Incompatible Speed                                            1490
# Alcohol Intake                                                1158
# Do not keep a safe distance                                   1033
# Mechanical Defect in the Vehicle                               894
# Driver Sleeping                                                626
# Slippery track                                                 611
# Pedestrian Lack of Attention                                   433
# Animals on the Track                                           357
# Undue Overtaking                                               286
# Road defect                                                    247
# Tire damage and/or excessive wear                              233
# ...

# %%
ax = df2.dead.hist()
ax.set_yscale('log')
ax.set_xlabel('death')
ax.set_ylabel('number 1of accidents')
# Out:
# Text(0, 0.5, 'number 1of accidents')

# %%
df2[df2['dead'] >= 2]['date'].count()
# Out:
# 122

# %%
ax = df2.weather_condition.hist()
#ax.set_yscale('log')
ax.set_xlabel('weather')
ax.set_ylabel('number 1of accidents')
# Out:
# Text(0, 0.5, 'number 1of accidents')

# %%
df2.head()
# Out:
#          date  weekday      time  municipality  \
# 0  2019-01-01        3  01:30:00     GUARULHOS
# 1  2019-01-01        3  01:30:00  PONTA GROSSA
# 2  2019-01-01        3  00:45:00        GARUVA
# 3  2019-01-01        3  00:00:00     FORTALEZA
# 4  2019-01-01        3  01:00:00      NOVA ERA
#
#                          accident_cause                 accident_type  \
# 0          Lack of Attention to Driving  Collision with static object
# 1          Lack of Attention to Driving                rear collision
# 2                  Animals on the Track  Collision with static object
# 3  Ingestion of Psychoactive Substances  Collision with static object
# 4          Lack of Attention to Driving          Transverse collision
#
#     classified_accident   phase_day   sense_via weather_condition  ... dead  \
# 0  With injured victims  Full Night     Growing         Clear sky  ...    0
# 1  With injured victims  Full Night     Growing            Cloudy  ...    0
# ...

# %%
#To play with df. apply and its axis
#nitialize list of lists
data = [[1, 10], [2, 2], [2, 14]]
  
# Create the pandas DataFrame
df6 = pd.DataFrame(data, columns=['A', 'B'])

def f(row):
    print(row)
    
    return 1

df6['c'] = df6.apply(f, axis = 0)
df6.head()
# Out:
# 0    1
# 1    2
# 2    2
# Name: A, dtype: int64
# 0    10
# 1     2
# 2    14
# Name: B, dtype: int64
#    A   B   c
# 0  1  10 NaN
# 1  2   2 NaN
# 2  2  14 NaN

# %%
df2.head()
# Out:
#          date  weekday      time  municipality  \
# 0  2019-01-01        3  01:30:00     GUARULHOS
# 1  2019-01-01        3  01:30:00  PONTA GROSSA
# 2  2019-01-01        3  00:45:00        GARUVA
# 3  2019-01-01        3  00:00:00     FORTALEZA
# 4  2019-01-01        3  01:00:00      NOVA ERA
#
#                          accident_cause                 accident_type  \
# 0          Lack of Attention to Driving  Collision with static object
# 1          Lack of Attention to Driving                rear collision
# 2                  Animals on the Track  Collision with static object
# 3  Ingestion of Psychoactive Substances  Collision with static object
# 4          Lack of Attention to Driving          Transverse collision
#
#     classified_accident   phase_day   sense_via weather_condition  ... dead  \
# 0  With injured victims  Full Night     Growing         Clear sky  ...    0
# 1  With injured victims  Full Night     Growing            Cloudy  ...    0
# ...

# %%
def create_y(df):
    def f(row):
        if row['severe_injured'] > 0 or row['dead'] > 0 :
            val = 1
        else:
            val = 0
        return val
    df['ambulance_called'] = df.apply(f, axis = 1)
        #lambda x: 1 if print(df['dead'] == 1), else 0, axis = 1)
                      #if df['dead'][x] == 0
        #1 if df['dead'] == 0  else 0, axis = 1)
        
        #df['ambulance_called'][x] = 1 | (df['severe_injured'] != 0
    return df
df3 = df2.copy()
df3 = create_y(df3)

# %%
df3.head(10)
# Out:
#          date  weekday      time           municipality  \
# 0  2019-01-01        3  01:30:00              GUARULHOS
# 1  2019-01-01        3  01:30:00           PONTA GROSSA
# 2  2019-01-01        3  00:45:00                 GARUVA
# 3  2019-01-01        3  00:00:00              FORTALEZA
# 4  2019-01-01        3  01:00:00               NOVA ERA
# 5  2019-01-01        3  01:50:00                 GASPAR
# 6  2019-01-01        3  01:30:00                  COXIM
# 7  2019-01-01        3  00:50:00                CATALAO
# 8  2019-01-01        3  02:25:00                GOIANIA
# 9  2019-01-01        3  02:15:00  BOA VISTA DAS MISSOES
#
#                                 accident_cause                 accident_type  \
# 0                 Lack of Attention to Driving  Collision with static object
# 1                 Lack of Attention to Driving                rear collision
# 2                         Animals on the Track  Collision with static object
# ...

# %%
df3.loc[df3.dead == 1]
# Out:
#              date  weekday      time           municipality  \
# 8      2019-01-01        3  02:25:00                GOIANIA
# 16     2019-01-01        3  03:00:00             CAJAZEIRAS
# 17     2019-01-01        3  03:30:00                MACAIBA
# 19     2019-01-01        3  04:00:00                IPUIUNA
# 22     2019-01-01        3  04:50:00              DOURADINA
# ...           ...      ...       ...                    ...
# 15503  2019-03-22        6  21:01:00  DOIS IRMAOS DO BURITI
# 15519  2019-03-16        7  20:05:00         CORONEL VIVIDA
# 15525  2019-02-19        3  16:00:00                 CAJATI
# 15569  2019-03-22        6  18:45:00       BARRA DO RIBEIRO
# 15584  2019-01-29        3  16:50:00               TERESINA
#
#                                     accident_cause            accident_type  \
# 8          Disobeying traffic rules by pedestrians  Pedestrian Running Over
# 16                    Lack of Attention to Driving        Head-on collision
# ...

# %%
#[-23,-24 - -46,-47]

# %%
df3.shape
# Out:
# (15588, 25)

# %%
np.head(100)
# Out:
#                0
# 0      GUARULHOS
# 1   PONTA GROSSA
# 2         GARUVA
# 3      FORTALEZA
# 4       NOVA ERA
# ..           ...
# 95       CAUCAIA
# 96         VIANA
# 97       IBATIBA
# 98   NOVA IGUACU
# 99       ITAGUAI
#
# [100 rows x 1 columns]

# %%
np = pd.DataFrame(df3['municipality'].unique())
np[np[0].str.startswith('SAO C')]
# Out:
#                         0
# 281  SAO CRISTOVAO DO SUL
# 439           SAO CAITANO
# 522         SAO CRISTOVAO

# %%
df3.loc[df3['municipality'] == 'São Paulo']
# Out:
# Empty DataFrame
# Columns: [date, weekday, time, municipality, accident_cause, accident_type, classified_accident, phase_day, sense_via, weather_condition, track_type, traced_via, use_only, people, dead, mild_injured, severe_injured, unharmed, ignored, injured, vehicles, latitude, longitude, regional, ambulance_called]
# Index: []
#
# [0 rows x 25 columns]

# %%
ndf = pd.read_csv("thai_road_accident_2019_2022.csv")
ndf.head()
# Out:
#    acc_code    incident_datetime      report_datetime      province_th  \
# 0    571905  2019-01-01 00:00:00  2019-01-02 06:11:00           ลพบุรี
# 1   3790870  2019-01-01 00:03:00  2020-02-20 13:48:00      อุบลราชธานี
# 2    599075  2019-01-01 00:05:00  2019-01-01 10:35:00  ประจวบคีรีขันธ์
# 3    571924  2019-01-01 00:20:00  2019-01-02 05:12:00        เชียงใหม่
# 4    599523  2019-01-01 00:25:00  2019-01-04 09:42:00        นครสวรรค์
#
#            province_en                     agency  \
# 0               Loburi  department of rural roads
# 1     Ubon Ratchathani     department of highways
# 2  Prachuap Khiri Khan     department of highways
# 3           Chiang Mai  department of rural roads
# 4         Nakhon Sawan     department of highways
#
#                                                route           vehicle_type  \
# 0  แยกทางหลวงหมายเลข 21 (กม.ที่ 31+000) - บ้านวัง...             motorcycle
# 1                              เดชอุดม - อุบลราชธานี  private/passenger car
# ...

# %%
ndf['province_en'].unique()
# Out:
# array(['Loburi', 'Ubon Ratchathani', 'Prachuap Khiri Khan', 'Chiang Mai',
#        'Nakhon Sawan', 'Mae Hong Son', 'Chumphon', 'Sing Buri',
#        'Songkhla', 'Trat', 'Lamphun', 'Phuket', 'Saraburi', 'Ratchaburi',
#        'Phra Nakhon Si Ayutthaya', 'Nakhon Ratchasima',
#        'Nakhon Si Thammarat', 'Kalasin', 'Chaiyaphum', 'Suphan Buri',
#        'Phetchaburi', 'Chai Nat', 'Phrae', 'Prachin Buri',
#        'Nakhon Pathom', 'Phetchabun', 'Ang Thong', 'Kanchanaburi',
#        'Nonthaburi', 'Samut Prakan', 'Bangkok', 'Phayao', 'Phatthalung',
#        'Yala', 'Maha Sarakham', 'Surat Thani', 'Amnat Charoen',
#        'Nong Khai', 'Nan', 'Phangnga', 'Narathiwat', 'Chanthaburi',
#        'Samut Sakhon', 'Samut Songkhram', 'Phitsanulok', 'Pathum Thani',
#        'Tak', 'Loei', 'Chiang Rai', 'Chachoengsao', 'Buri Ram',
#        'Uthai Thani', 'Krabi', 'Surin', 'Udon Thani', 'Si Sa Ket',
#        'Uttaradit', 'Khon Kaen', 'Kamphaeng Phet', 'Yasothon', 'Satun',
# ...

# %%
ndf2 = ndf[ndf['province_en'] == 'Bangkok']

# %%
ndf2.head()
# Out:
#      acc_code    incident_datetime      report_datetime    province_th  \
# 47     629691  2019-01-01 03:05:00  2019-01-01 03:05:00  กรุงเทพมหานคร
# 81     629689  2019-01-01 05:42:00  2019-01-01 05:42:00  กรุงเทพมหานคร
# 120    604307  2019-01-01 10:10:00  2019-03-06 10:49:00  กรุงเทพมหานคร
# 240   3793736  2019-01-01 17:30:00  2020-03-11 13:15:00  กรุงเทพมหานคร
# 275    599070  2019-01-01 19:20:00  2019-01-01 20:57:00  กรุงเทพมหานคร
#
#     province_en                            agency  \
# 47      Bangkok  expressway authority of thailand
# 81      Bangkok  expressway authority of thailand
# 120     Bangkok            department of highways
# 240     Bangkok            department of highways
# 275     Bangkok            department of highways
#
#                             route           vehicle_type  \
# 47              บางพลี-สุขสวัสดิ์                  other
# 81                   บางนา-ชลบุรี                  other
# 120             ดาวคะนอง -  แสมดำ  private/passenger car
# ...

# %%
ndf3 = ndf2[ndf2['number_of_fatalities'] > 0]
ndf3.count()
# Out:
# acc_code                       110
# incident_datetime              110
# report_datetime                110
# province_th                    110
# province_en                    110
# agency                         110
# route                          110
# vehicle_type                   110
# presumed_cause                 110
# accident_type                  110
# number_of_vehicles_involved    110
# number_of_fatalities           110
# number_of_injuries             110
# weather_condition              110
# latitude                       105
# longitude                      105
# road_description               110
# slope_description              110
# dtype: int64

# %% [markdown]
# ambulance_called is an important feature. But out y, is the location. We want to predict where the crash might happen.

# %%
df4 = pd.get_dummies(df3, )
